# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[2, 5, 5], [0, 0, 1]])
X
# Out:
# array([[2, 5, 5],
#        [0, 0, 1]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([2, 0])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([0, 0, 1])

# %% [markdown]
# 2. ulangi soal nomor 1 menggunakan Pytorch

# %%
import torch

# %%
X_pt = torch.tensor([[2, 5, 5], [0, 0, 1]])
X_pt
# Out:
# tensor([[2, 5, 5],
#         [0, 0, 1]])

# %%
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
X_pt[:,0]
# Out:
# tensor([2, 0])

# %%
X_pt[1,:]
# Out:
# tensor([0, 0, 1])

# %% [markdown]
# 3. ulangi soal nomor 1 menggunakan Tensorflow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[2, 5, 5], [0, 0, 1]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[2, 5, 5],
#        [0, 0, 1]], dtype=int32)>

# %%
X_tf.shape
# Out:
# TensorShape([2, 3])

# %%
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 0], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 1], dtype=int32)>
